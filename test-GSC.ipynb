# %% [markdown]
# # TimeSeries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
bitcoin = pd.read_csv('BTC-EUR.csv')

# %%
bitcoin.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#        Volume
# 0  16389166.0
# 1  26691849.0
# 2  29560103.0
# 3  28736826.0
# 4  20702625.0

# %% [markdown]
# ## Observation des données de Close du bitcoin

# %%
bitcoin['Close'].plot(figsize=(9,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Travailler sur une base temporelle : DateTimeIndex

# %%
bitcoin.index
# Out:
# RangeIndex(start=0, stop=3037, step=1)

# %%
bitcoin = pd.read_csv('BTC-EUR.csv', index_col='Date')
bitcoin.index
# Out:
# Index(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20', '2014-09-21',
#        '2014-09-22', '2014-09-23', '2014-09-24', '2014-09-25', '2014-09-26',
#        ...
#        '2022-12-31', '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#        '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09'],
#       dtype='object', name='Date', length=3037)

# %%
bitcoin['Close'].plot(figsize=(9,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Indiquer à pandas que la colonne représente des dates

# %%
bitcoin = pd.read_csv('BTC-EUR.csv', index_col='Date', parse_dates=True)
bitcoin.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2022-12-31', '2023-01-01', '2023-01-02', '2023-01-03',
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-07',
#                '2023-01-08', '2023-01-09'],
#               dtype='datetime64[ns]', name='Date', length=3037, freq=None)

# %% [markdown]
# ## Analyse des données : Années, mois, semaines, jours etc..

# %% [markdown]
# ### 2019

# %%
bitcoin['2019']['Close'].plot()
# Out:
# C:\Users\fredd\AppData\Local\Temp\ipykernel_19344\242990758.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   bitcoin['2019']['Close'].plot()
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Septembre 2019

# %%
bitcoin['2019-09']['Close'].plot()
# Out:
# C:\Users\fredd\AppData\Local\Temp\ipykernel_19344\361147746.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   bitcoin['2019-09']['Close'].plot()
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Exemple de slicing : Entre 2017 et 2019

# %%
bitcoin['2017':'2019']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Exemple avec la méthode loc

# %%
bitcoin.loc['2017':'2019']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Resample : Regrouper nos données selon une fréquence temporelle
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2019 : regroupement par mois

# %%
bitcoin.loc['2019', 'Close'].resample('M').plot()
plt.show()

# %% [markdown]
# ### 2019 : La moyenne sur chaque mois

# %%
bitcoin.loc['2019', 'Close'].resample('M').mean().plot()
plt.show()

# %% [markdown]
# ### 2019 : La moyenne sur chaque semaine

# %%
bitcoin.loc['2019', 'Close'].resample('W').mean().plot()
plt.show()

# %% [markdown]
# ### 2019 : La moyenne toute les 2 semaine

# %%
bitcoin.loc['2019', 'Close'].resample('2W').mean().plot()
plt.show()

# %% [markdown]
# ### 2019 : Ecart type du bitcoin en 2019
# Observations : Le bitcoin était très volatile en 2019

# %%
bitcoin.loc['2019', 'Close'].resample('2W').std().plot()
plt.show()

# %% [markdown]
# ### Afficher toutes les courbes sur un seul et même graphique (pratique courante)

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019', 'Close'].plot()
bitcoin.loc['2019', 'Close'].resample('M').mean().plot(label='Moyenne par mois', lw=3, ls=':', alpha=0.8)
bitcoin.loc['2019', 'Close'].resample('W').mean().plot(label='Moyenne par semaine', lw=2, ls='--', alpha=0.8)
plt.legend()
plt.show()

# %% [markdown]
# ## Aggregate
# Rassembler dans un seul tableau plusieurs statistiques qu'on aimerais faire par dessus resample

# %% [markdown]
# ### 2019 :

# %%
bitcoin.loc['2019', 'Close'].resample('W').agg(['mean', 'std', 'min', 'max'])
# Out:
#                     mean         std           min           max
# Date
# 2019-01-06   3422.916626   86.768296   3353.505859   3572.601807
# 2019-01-13   3317.593401  180.066248   3100.221680   3518.607910
# 2019-01-20   3216.173340   36.646566   3168.373535   3280.021484
# 2019-01-27   3157.861154   15.218334   3140.374756   3183.176025
# 2019-02-03   3035.448347   19.472269   3015.454102   3073.150146
# 2019-02-10   3114.468541  123.483779   2998.157227   3258.583740
# 2019-02-17   3222.201835   17.498269   3202.042725   3252.190186
# 2019-02-24   3500.129360   88.628342   3359.558594   3653.833008
# 2019-03-03   3392.695312   12.224585   3381.982910   3416.384521
# 2019-03-10   3460.863769   70.371025   3317.817383   3527.745605
# 2019-03-17   3496.058245   48.519390   3447.834229   3572.190918
# 2019-03-24   3564.463972   14.186751   3542.431152   3585.598877
# 2019-03-31   3608.873884   63.797987   3502.470703   3659.444824
# 2019-04-07   4358.025565  299.981771   3710.858154   4634.541016
# 2019-04-14   4588.227260   94.949556   4497.265137   4722.057617
# 2019-04-21   4668.041085   91.129434   4482.450195   4746.688477
# 2019-04-28   4790.460380  104.405929   4678.542969   4964.707031
# 2019-05-05   4963.551130  212.508625   4690.791992   5203.150879
# 2019-05-12   5640.518276  495.308810   5130.174805   6413.687988
# 2019-05-19   6986.585240  330.929139   6513.402832   7342.637695
# 2019-05-26   7179.602260  265.214279   6884.596191   7737.375977
# 2019-06-02   7722.894182  136.802859   7473.814453   7866.871094
# 2019-06-09   6993.607840  168.288002   6791.208984   7299.265625
# 2019-06-16   7457.876395  411.088094   6997.714355   8017.551758
# 2019-06-23   8706.575963  578.209060   8109.805176   9536.269531
# 2019-06-30  10320.506836  701.342943   9520.881836  11443.038086
# 2019-07-07   9918.506557  404.681380   9376.392578  10597.433594
# 2019-07-14  10391.320173  709.415971   9098.846680  11221.008789
# 2019-07-21   9235.699219  485.655088   8452.749023   9674.610352
# 2019-07-28   8823.355190  234.706282   8510.954102   9229.929688
# 2019-08-04   9244.097238  517.775427   8542.986328   9875.908203
# 2019-08-11  10423.275112  232.958950  10065.183594  10697.322266
# 2019-08-18   9442.795899  380.082098   9021.052734  10148.331055
# 2019-08-25   9319.825753  321.021603   9042.080078   9849.555664
# 2019-09-01   8895.254604  269.061355   8598.343750   9342.159180
# 2019-09-08   9504.869280  126.488142   9302.545898   9681.073242
# 2019-09-15   9302.957171   83.923461   9155.443359   9416.116211
# 2019-09-22   9228.095005   85.257241   9092.541992   9338.717773
# 2019-09-29   7763.493094  503.726126   7405.604980   8850.279297
# 2019-10-06   7513.332380  136.332493   7272.209473   7657.534180
# 2019-10-13   7611.955287  137.234606   7508.353027   7824.074707
# 2019-10-20   7320.396764  161.911202   7138.117676   7595.379883
# 2019-10-27   7561.077079  733.792125   6748.621094   8617.566406
# 2019-11-03   8319.293387   82.717590   8245.560547   8483.099609
# 2019-11-10   8277.292411  210.428453   7990.455566   8458.521484
# 2019-11-17   7860.784947  131.967663   7684.157227   8005.502930
# 2019-11-24   6970.247001  423.754016   6394.292969   7504.623047
# 2019-12-01   6758.916853  190.822260   6490.004395   7043.895020
# 2019-12-08   6709.069754  124.893115   6543.503418   6839.696289
# 2019-12-15   6511.581822   95.334097   6406.791992   6689.006836
# 2019-12-22   6427.132464  263.670741   5954.815430   6779.712402
# 2019-12-29   6574.883929   48.954934   6521.947266   6638.048340
# 2020-01-05   6461.097168   70.196921   6411.460449   6510.733887

# %%
m = bitcoin['Close'].resample('W').agg(['mean', 'std', 'min', 'max'])

plt.figure(figsize=(12,8))
m['mean']['2019'].plot(label='Moyenne par semaine')
plt.fill_between(m.index, m['max'], m['min'], alpha=0.2, label='Min-max par semaine')

plt.legend()
plt.show()

# %% [markdown]
# ## Moving Average
# Une technique qui permet de calculer une moyenne mais plutot que de faire la moyenne de toutes les valeurs que l'on aurait (par exemple) en 2019, on va faire la moyenne sur une **fenettre de valeurs**. Exemple pour une fenettre de 7 jours, on va calculer la moyenne, puis on va se décaler d'un jour dans cette fenettre, puis on recalcule la moyenne etc. Donc avec pandas on va executer une fonction qui effecture un roulement (**rolling**) et à l'intérieur de cette fonction qui effectue un roulement, on va définir une taille pour notre fenettre (**fenettre de valeur** => **window**)
#
# ![image.png](attachment:image.png)

# %%
bitcoin.loc['2019', 'Close'].rolling(window=7)
# Out:
# Rolling [window=7,center=False,axis=0,method=single]

# %% [markdown]
# ### Utiliser cette fonction pour calculer une moyenne

# %%
bitcoin.loc['2019', 'Close'].rolling(window=7).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 2019 : Comparaison avec le signal original

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019', 'Close'].plot()
bitcoin.loc['2019', 'Close'].rolling(window=7).mean().plot(label='Moving average', lw=3, ls=':', alpha=0.8)

plt.legend()
plt.show()

# %% [markdown]
# ### Septembre 2019

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019-09', 'Close'].plot()
bitcoin.loc['2019-09', 'Close'].rolling(window=7).mean().plot(label='Moving average', lw=3, ls=':', alpha=0.8)

plt.legend()
plt.show()

# %% [markdown]
# ### 2019 : Moving average par le centre de la fenettre
#
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019-09', 'Close'].plot()
bitcoin.loc['2019-09', 'Close'].rolling(window=7).mean().plot(label='Moving average', lw=3, ls=':', alpha=0.8)
bitcoin.loc['2019-09', 'Close'].rolling(window=7, center=True).mean().plot(label='Moving average from window center', lw=3, ls=':', alpha=0.8)

plt.legend()
plt.show()

# %% [markdown]
# ## Exponential Weighted Function

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019-09', 'Close'].plot()
bitcoin.loc['2019-09', 'Close'].rolling(window=7).mean().plot(label='Moving average', lw=3, ls=':', alpha=0.8)
bitcoin.loc['2019-09', 'Close'].rolling(window=7, center=True).mean().plot(label='Moving average from window center', lw=3, ls=':', alpha=0.8)
bitcoin.loc['2019-09', 'Close'].ewm(alpha=0.6).mean().plot(label='Moving average from window center', lw=3, ls=':', alpha=0.8)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019-09', 'Close'].plot()
for i in np.arange(0.2, 1, 0.2):
    bitcoin.loc['2019-09', 'Close'].ewm(alpha=i).mean().plot(label=f'ewm {i}', lw=3, ls=':', alpha=0.8)

plt.legend()
plt.show()

# %% [markdown]
# # Assembler des datasets

# %%
ethereum = pd.read_csv('ETH-EUR.csv', index_col='Date', parse_dates=True)
ethereum.index
# Out:
# DatetimeIndex(['2017-11-11', '2017-11-12', '2017-11-13', '2017-11-14',
#                '2017-11-15', '2017-11-16', '2017-11-17', '2017-11-18',
#                '2017-11-19', '2017-11-20',
#                ...
#                '2022-12-31', '2023-01-01', '2023-01-02', '2023-01-03',
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-07',
#                '2023-01-08', '2023-01-09'],
#               dtype='datetime64[ns]', name='Date', length=1886, freq=None)

# %%
ethereum['2019']['Close'].plot()
# Out:
# C:\Users\fredd\AppData\Local\Temp\ipykernel_19344\3896088478.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ethereum['2019']['Close'].plot()
# <AxesSubplot:xlabel='Date'>

# %%
pd.merge(bitcoin, ethereum, on='Date', how='inner')
# Out:
#                   Open_x        High_x         Low_x       Close_x  \
# Date
# 2017-11-11   5674.877930   5893.123535   5319.574707   5451.084473
# 2017-11-12   5397.796387   5680.399414   4732.066895   5102.976074
# 2017-11-13   5092.838867   5835.995117   5016.558105   5624.187988
# 2017-11-14   5625.894043   5796.897949   5494.685547   5628.764160
# 2017-11-15   5627.924316   6227.523438   5626.492188   6209.081543
# ...                  ...           ...           ...           ...
# 2023-01-05  15900.061523  15902.215820  15902.749023  16002.543945
# 2023-01-06  16002.293945  15960.681641  15921.389648  15896.708984
# 2023-01-07  15896.847656  15945.719727  15861.756836  15900.098633
# 2023-01-08           NaN           NaN           NaN           NaN
# 2023-01-09  16054.547852  16149.099609  16049.909180  16105.882813
#
#              Adj Close_x      Volume_x       Open_y       High_y        Low_y  \
# Date
# 2017-11-11   5451.084473  4.208763e+09   256.011322   273.902954   255.673492
# 2017-11-12   5102.976074  7.682118e+09   269.819092   273.739624   255.948730
# 2017-11-13   5624.187988  5.370188e+09   263.314758   281.949707   263.405121
# 2017-11-14   5628.764160  2.711943e+09   271.596497   290.873871   271.573212
# 2017-11-15   6209.081543  3.565507e+09   286.677399   289.079956   279.644714
# ...                  ...           ...          ...          ...          ...
# 2023-01-05  16002.543945  1.301434e+10  1184.701660  1185.385620  1180.071655
# 2023-01-06  15896.708984  1.351641e+10  1188.503784  1196.045410  1182.728394
# 2023-01-07  15900.098633  7.234739e+09  1190.398315  1193.554321  1183.730103
# 2023-01-08           NaN           NaN          NaN          NaN          NaN
# 2023-01-09  16105.882813  1.257839e+10  1208.034912  1234.448242  1207.999146
#
#                 Close_y  Adj Close_y      Volume_y
# Date
# 2017-11-11   269.811371   269.811371  7.221993e+08
# 2017-11-12   264.072021   264.072021  1.383774e+09
# 2017-11-13   271.556213   271.556213  8.933293e+08
# 2017-11-14   286.394958   286.394958  9.073543e+08
# 2017-11-15   282.937531   282.937531  6.133644e+08
# ...                 ...          ...           ...
# 2023-01-05  1188.484375  1188.484375  3.803514e+09
# 2023-01-06  1190.360107  1190.360107  4.667419e+09
# 2023-01-07  1185.604858  1185.604858  2.405601e+09
# 2023-01-08          NaN          NaN           NaN
# 2023-01-09  1234.448242  1234.448242  5.670804e+09
#
# [1886 rows x 12 columns]

# %%
pd.merge(bitcoin, ethereum, on='Date', how='outer', suffixes=('_btc', '_eth'))
# Out:
#                 Open_btc      High_btc       Low_btc     Close_btc  \
# Date
# 2014-09-17    359.546204    361.468506    351.586884    355.957367
# 2014-09-18    355.588409    355.505402    319.789459    328.539368
# 2014-09-19    328.278503    330.936707    298.921021    307.761139
# 2014-09-20    307.665253    329.978180    303.931244    318.758972
# 2014-09-21    318.120514    321.504517    306.502197    310.632446
# ...                  ...           ...           ...           ...
# 2023-01-05  15900.061523  15902.215820  15902.749023  16002.543945
# 2023-01-06  16002.293945  15960.681641  15921.389648  15896.708984
# 2023-01-07  15896.847656  15945.719727  15861.756836  15900.098633
# 2023-01-08           NaN           NaN           NaN           NaN
# 2023-01-09  16054.547852  16149.099609  16049.909180  16105.882813
#
#             Adj Close_btc    Volume_btc     Open_eth     High_eth  \
# Date
# 2014-09-17     355.957367  1.638917e+07          NaN          NaN
# 2014-09-18     328.539368  2.669185e+07          NaN          NaN
# 2014-09-19     307.761139  2.956010e+07          NaN          NaN
# 2014-09-20     318.758972  2.873683e+07          NaN          NaN
# 2014-09-21     310.632446  2.070262e+07          NaN          NaN
# ...                   ...           ...          ...          ...
# 2023-01-05   16002.543945  1.301434e+10  1184.701660  1185.385620
# 2023-01-06   15896.708984  1.351641e+10  1188.503784  1196.045410
# 2023-01-07   15900.098633  7.234739e+09  1190.398315  1193.554321
# 2023-01-08            NaN           NaN          NaN          NaN
# 2023-01-09   16105.882813  1.257839e+10  1208.034912  1234.448242
#
#                 Low_eth    Close_eth  Adj Close_eth    Volume_eth
# Date
# 2014-09-17          NaN          NaN            NaN           NaN
# 2014-09-18          NaN          NaN            NaN           NaN
# 2014-09-19          NaN          NaN            NaN           NaN
# 2014-09-20          NaN          NaN            NaN           NaN
# 2014-09-21          NaN          NaN            NaN           NaN
# ...                 ...          ...            ...           ...
# 2023-01-05  1180.071655  1188.484375    1188.484375  3.803514e+09
# 2023-01-06  1182.728394  1190.360107    1190.360107  4.667419e+09
# 2023-01-07  1183.730103  1185.604858    1185.604858  2.405601e+09
# 2023-01-08          NaN          NaN            NaN           NaN
# 2023-01-09  1207.999146  1234.448242    1234.448242  5.670804e+09
#
# [3037 rows x 12 columns]

# %%
btc_eth = pd.merge(bitcoin, ethereum, on='Date', how='inner', suffixes=('_btc', '_eth'))

# %%
btc_eth[['Close_btc', 'Close_eth']].plot(figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Pour que les 2 datasets soient plus lisibles à leurs échel

# %%
btc_eth[['Close_btc', 'Close_eth']].plot(subplots=True, figsize=(12, 8))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %% [markdown]
# ### Obtenir la matrice de correlation
#
# Ici 0.927807 => 92% de correlation. (Observation : Très élevé)

# %%
btc_eth[['Close_btc', 'Close_eth']].corr()
# Out:
#            Close_btc  Close_eth
# Close_btc   1.000000   0.927807
# Close_eth   0.927807   1.000000

# %%
import seaborn as sns
correlations = btc_eth[['Close_btc', 'Close_eth']].corr()
sns.heatmap(correlations)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exercice : Trading Strategy => Turtle Strategy
# Vielle technique de trading afin de décider quand acheter ou vendre du bitcoin en fonction de la valeur de 'Close' par rapport au minimum ou au maximum des 28 derniers jours.

# %%
bitcoin['Close']['2019'].diff().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin['Close']['2019-06': '2019-07'].diff().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# %matplotlib

# %%
data = bitcoin.copy()
data['Buy'] = np.zeros(len(data))
data['Sell'] = np.zeros(len(data))

# %%
data['RollingMax'] = data['Close'].shift(1).rolling(window=5).max()
data['RollingMin'] = data['Close'].shift(1).rolling(window=5).min()
data.loc[data['RollingMax'] < data['Close'], 'Buy'] = 1
data.loc[data['RollingMin'] > data['Close'], 'Sell'] = -1

# %%
start = '2019-06-02'
end = '2019-06-03'
fig, ax = plt.subplots(2, figsize=(12, 8), sharex=True)
#plt.figure(figsize=(12 8))
#plt.subplot(211)
ax[0].plot(data['Close'][start:end])
ax[0].plot(data['RollingMax'][start:end])
ax[0].plot(data['RollingMin'][start:end])
ax[0].legend(['close', 'min', 'max'])
ax[1].plot(data['Buy'][start:end], c='g')
ax[1].plot(data['Sell'][start:end], c='r')
ax[1].legend(['buy', 'sell'])
